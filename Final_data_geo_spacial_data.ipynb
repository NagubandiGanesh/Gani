# %%
import urllib.parse,urllib.request,urllib.error
import pandas as pd

#!conda install -c conda-fo beautifulsoup4
from bs4 import BeautifulSoup

# The down two lines of code are regarding opening of url and downloading the data
url  = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
html = urllib.request.urlopen(url)

# This line is cleaning the HTML code with BeautifulSoup
soup = BeautifulSoup(html,'html.parser')

# Then inserting the table data of the wikipedia page 
table = soup.find_all('table')[0] 

# Now loading the Data to list using pandas read_html
lst = pd.read_html(str(table))

# Converting List to pandas data frame 
df = pd.DataFrame(lst[0])

# %%
# Removing the Not assigned Borough from data frame
df = df[df["Borough"] != "Not assigned"]

# %%
print(df.shape)

df['ADDRESS'] = df['Neighbourhood'] + ', ' + df['Borough'] + ', ' + df['Postcode']

df.head()
# Out:
# (210, 3)
#   Postcode           Borough     Neighbourhood  \
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor
#
#                                ADDRESS
# 2           Parkwoods, North York, M3A
# 3    Victoria Village, North York, M4A
# 4  Harbourfront, Downtown Toronto, M5A
# 5    Lawrence Heights, North York, M6A
# 6      Lawrence Manor, North York, M6A

# %%
latlong = pd.read_csv('Geospatial_Coordinates.csv')
latlong.columns
Result = df.merge(latlong,left_on='Postcode',right_on='Postal Code')
Result = Result[["Postcode","Borough","Neighbourhood","Latitude","Longitude"]]
Result
# Out:
#     Postcode           Borough             Neighbourhood   Latitude  Longitude
# 0        M3A        North York                 Parkwoods  43.753259 -79.329656
# 1        M4A        North York          Victoria Village  43.725882 -79.315572
# 2        M5A  Downtown Toronto              Harbourfront  43.654260 -79.360636
# 3        M6A        North York          Lawrence Heights  43.718518 -79.464763
# 4        M6A        North York            Lawrence Manor  43.718518 -79.464763
# ..       ...               ...                       ...        ...        ...
# 205      M8Z         Etobicoke  Kingsway Park South West  43.628841 -79.520999
# 206      M8Z         Etobicoke                 Mimico NW  43.628841 -79.520999
# 207      M8Z         Etobicoke        The Queensway West  43.628841 -79.520999
# 208      M8Z         Etobicoke     Royal York South West  43.628841 -79.520999
# 209      M8Z         Etobicoke            South of Bloor  43.628841 -79.520999
#
# [210 rows x 5 columns]
