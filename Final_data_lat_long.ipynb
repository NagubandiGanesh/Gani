# %%
import urllib.parse,urllib.request,urllib.error
import pandas as pd

#!conda install -c conda-fo beautifulsoup4
from bs4 import BeautifulSoup

# The down two lines of code are regarding opening of url and downloading the data
url  = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
html = urllib.request.urlopen(url)

# This line is cleaning the HTML code with BeautifulSoup
soup = BeautifulSoup(html,'html.parser')

# Then inserting the table data of the wikipedia page 
table = soup.find_all('table')[0] 

# Now loading the Data to list using pandas read_html
lst = pd.read_html(str(table))

# Converting List to pandas data frame 
df = pd.DataFrame(lst[0])

# %%
# Removing the Not assigned Borough from data frame
df = df[df["Borough"] != "Not assigned"]

# %%
print(df.shape)
df.head()
# Out:
# (210, 5)
#   Postcode           Borough     Neighbourhood   Latitude  Longitude
# 2      M3A        North York         Parkwoods   0.000000   0.000000
# 3      M4A        North York  Victoria Village  43.722778 -79.450933
# 4      M5A  Downtown Toronto      Harbourfront  43.722079 -79.437507
# 5      M6A        North York  Lawrence Heights   0.000000   0.000000
# 6      M6A        North York    Lawrence Manor  53.740434  -2.460322

# %%
from geopy.geocoders import Nominatim # import geocoder

latitude = []
longitude = []

address_register = list( df["Borough"] +", " + df["Postcode"]  )

print(len(address_register))

geocoder = Nominatim() 

for address in address_register:
    try:
        location = geocoder.geocode(address)
        latitude.append(location.latitude)
        longitude.append(location.longitude)

    except:
        latitude.append(0.0)
        longitude.append(0.0)
# Out:
# 210
# C:\Users\ganeshsubramanyam\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   # Remove the CWD from sys.path while we load stuff.

# %%
df["Latitude"]  = pd.DataFrame(latitude)
df["Longitude"] = pd.DataFrame(longitude)
print(df.shape)
# Out:
# (210, 5)

# %%
df.head(15)
# Out:
#    Postcode           Borough     Neighbourhood   Latitude  Longitude
# 2       M3A        North York         Parkwoods   0.000000   0.000000
# 3       M4A        North York  Victoria Village  43.722778 -79.450933
# 4       M5A  Downtown Toronto      Harbourfront  43.722079 -79.437507
# 5       M6A        North York  Lawrence Heights   0.000000   0.000000
# 6       M6A        North York    Lawrence Manor  53.740434  -2.460322
# 7       M7A      Queen's Park      Not assigned   0.000000   0.000000
# 9       M9A      Queen's Park      Queen's Park  43.775347 -79.345944
# 10      M1B       Scarborough             Rouge  43.712078 -79.302567
# 11      M1B       Scarborough           Malvern   0.000000   0.000000
# 13      M3B        North York   Don Mills North  43.662276 -79.376203
# 14      M4B         East York  Woodbine Gardens  43.708712 -79.440685
# 15      M4B         East York     Parkview Hill  43.633637 -79.549745
# 16      M5B  Downtown Toronto           Ryerson  43.645338 -79.524870
# 17      M5B  Downtown Toronto   Garden District  43.671459 -79.552492
# 18      M6B        North York         Glencairn  43.678856 -79.556456
